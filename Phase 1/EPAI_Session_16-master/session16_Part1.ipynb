# %% [markdown]
# ### Importing library

# %%
from collections import namedtuple
from datetime import datetime

# %% [markdown]
# ### Goal 1:

# %%
def read_csv(file_name, data_types = False):
    '''This function takes a csv file name and creates an iterator for reading the data'''

    def cast(data_type, value):
        '''This function changes the data format to required format'''
        if data_type == 'DOUBLE':
            return float(value)
        elif data_type == 'DATE':
            value = value[:10]
            if '/' in value:
                return datetime.strptime(value, '%Y/%m/%d')
            else:
                return datetime.strptime(value, '%Y-%m-%d')
        elif data_type == 'INT':
            return int(value)
        else:
            return str(value)

    def cast_row(data_types, data_row):
        '''This function changes the data format of the whole record to required format'''
        if data_types == False:
            return [cast("STRING", value) 
                    for value in data_row]
        else:
            return [cast(data_type, value) 
                    for data_type, value in zip(data_types, data_row)]

    with open(file_name) as file:
        Data = namedtuple('Data', next(iter(file)).strip('\n').replace(' ','_').split(','))
        for line in iter(file):
            yield Data(*cast_row(data_types,line.strip('\n').split(',')))

# %%
data_types = ['STRING', 'STRING', 'STRING', 'STRING']
employment = read_csv('employment.csv', data_types)

data_types = ['STRING', 'STRING', 'STRING', 'STRING', 'STRING']
personal_info = read_csv('personal_info.csv', data_types)

data_types = ['STRING', 'DATE', 'DATE']
update_status = read_csv('update_status.csv', data_types)

data_types = ['STRING', 'STRING', 'STRING', 'INT']
vehicles = read_csv('vehicles.csv', data_types)

# %% [markdown]
# ### Goal 2:

# %%
class Merge:
    def __init__(self, file_name_list, data_type_list):
        self.file_name_list = file_name_list
        self.data_type_list = data_type_list

    def __iter__(self):
        # return IteratorMerge.iterator_gen(self.iterator)
        return self.IteratorMerge(self)

    @staticmethod
    def iterator_gen(itr_list):
        fields = next(itr_list[0])._fields
        for i in range(1, len(itr_list)):
            fields = fields + next(itr_list[i])._fields[1:]
        DataN = namedtuple("DataN", fields)
        for line1, line2, line3, line4 in zip(*itr_list):
            yield DataN(*line1, *line2[1:], *line3[1:], *line4[1:])

    class IteratorMerge:
        def __init__(self, iterator_obj):
            self.iterator_obj = iterator_obj
 
        def __iter__(self):
            return self
            
        def __next__(self):
            employment = read_csv(self.iterator_obj.file_name_list[0], self.iterator_obj.data_type_list[0])
            personal_info = read_csv(self.iterator_obj.file_name_list[1], self.iterator_obj.data_type_list[1])
            update_status = read_csv(self.iterator_obj.file_name_list[2], self.iterator_obj.data_type_list[2])
            vehicles = read_csv(self.iterator_obj.file_name_list[3], self.iterator_obj.data_type_list[3])

            return Merge.iterator_gen([employment, personal_info, update_status, vehicles])

# %%
data_types_empl = ['STRING', 'STRING', 'STRING', 'STRING']

data_types_pinfo = ['STRING', 'STRING', 'STRING', 'STRING', 'STRING']

data_types_ustatus = ['STRING', 'DATE', 'DATE']

data_types_vcl = ['STRING', 'STRING', 'STRING', 'INT']

file_name = ['employment.csv', 'personal_info.csv', 'update_status.csv', 'vehicles.csv']

data_type = [data_types_empl, data_types_pinfo, data_types_ustatus, data_types_vcl]

all_data = Merge(file_name, data_type)

# %%
for x in next(iter(all_data)):
    print(x)
# Out:
# DataN(employer='Nicolas and Sons', department='Sales', employee_id='41-6841359', ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 1, 23, 0, 0), created=datetime.datetime(2016, 1, 27, 0, 0), vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# DataN(employer='Connelly Group', department='Research and Development', employee_id='98-7952860', ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', last_updated=datetime.datetime(2017, 10, 4, 0, 0), created=datetime.datetime(2016, 9, 21, 0, 0), vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# DataN(employer='Upton LLC', department='Marketing', employee_id='56-9817552', ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2017, 3, 28, 0, 0), created=datetime.datetime(2016, 4, 15, 0, 0), vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# DataN(employer='Zemlak-Olson', department='Business Development', employee_id='46-2886707', ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2018, 2, 19, 0, 0), created=datetime.datetime(2016, 3, 15, 0, 0), vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)
# DataN(employer='"Kohler', department=' Bradtke and Davis"', employee_id='Support', ssn='80-0975518', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', last_updated=datetime.datetime(2017, 7, 24, 0, 0), created=datetime.datetime(2016, 7, 23, 0, 0), vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# DataN(employer='"Roberts', department=' Torphy and Dach"', employee_id='Human Resources', ssn='77-4895332', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', last_updated=datetime.datetime(2018, 2, 14, 0, 0), created=datetime.datetime(2016, 12, 15, 0, 0), vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# DataN(employer='Lind-Jast', department='Marketing', employee_id='79-6418731', ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', last_updated=datetime.datetime(2018, 3, 24, 0, 0), created=datetime.datetime(2016, 3, 24, 0, 0), vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000)
# DataN(employer='Bashirian-Lueilwitz', department='Engineering', employee_id='44-3328799', ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian', last_updated=datetime.datetime(2017, 5, 11, 0, 0), created=datetime.datetime(2016, 5, 31, 0, 0), vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# DataN(employer='"Windler', department=' Marks and Haley"', employee_id='Services', ssn='54-6271885', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 10, 21, 0, 0), created=datetime.datetime(2016, 9, 8, 0, 0), vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992)
# DataN(employer='Leffler-Hahn', department='Accounting', employee_id='31-5735282', ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', last_updated=datetime.datetime(2017, 3, 18, 0, 0), created=datetime.datetime(2016, 5, 16, 0, 0), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# DataN(employer='Lueilwitz LLC', department='Marketing', employee_id='33-9146042', ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', last_updated=datetime.datetime(2017, 9, 4, 0, 0), created=datetime.datetime(2016, 9, 12, 0, 0), vehicle_make='Ford', vehicle_model='Mustang', model_year=1990)
# DataN(employer='Davis Inc', department='Accounting', employee_id='39-0400385', ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', last_updated=datetime.datetime(2017, 3, 18, 0, 0), created=datetime.datetime(2016, 8, 21, 0, 0), vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# DataN(employer='Kunze LLC', department='Research and Development', employee_id='78-2612900', ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch', last_updated=datetime.datetime(2018, 2, 5, 0, 0), created=datetime.datetime(2016, 7, 15, 0, 0), vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011)
# DataN(employer='"Mayert', department=' Rice and Schmitt"', employee_id='Product Management', ssn='85-8596488', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 6, 16, 0, 0), created=datetime.datetime(2016, 5, 28, 0, 0), vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# DataN(employer='Pouros LLC', department='Legal', employee_id='14-2589283', ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', last_updated=datetime.datetime(2017, 10, 30, 0, 0), created=datetime.datetime(2016, 6, 4, 0, 0), vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009)
# DataN(employer='Pfannerstill Group', department='Research and Development', employee_id='43-1532437', ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', last_updated=datetime.datetime(2017, 3, 10, 0, 0), created=datetime.datetime(2016, 10, 17, 0, 0), vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009)
# DataN(employer='Ryan Group', department='Sales', employee_id='08-8274517', ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian', last_updated=datetime.datetime(2017, 11, 21, 0, 0), created=datetime.datetime(2016, 7, 3, 0, 0), vehicle_make='Buick', vehicle_model='Rainier', model_year=2004)
# DataN(employer='Ritchie-Pagac', department='Business Development', employee_id='38-0095184', ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', last_updated=datetime.datetime(2017, 9, 1, 0, 0), created=datetime.datetime(2016, 12, 1, 0, 0), vehicle_make='Scion', vehicle_model='tC', model_year=2008)
# DataN(employer='Schmeler and Sons', department='Research and Development', employee_id='62-3275199', ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew', last_updated=datetime.datetime(2017, 2, 18, 0, 0), created=datetime.datetime(2016, 2, 2, 0, 0), vehicle_make='Audi', vehicle_model='S6', model_year=2009)
# DataN(employer='Kerluke-Dibbert', department='Services', employee_id='90-5121197', ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', last_updated=datetime.datetime(2017, 11, 2, 0, 0), created=datetime.datetime(2016, 4, 18, 0, 0), vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007)
# DataN(employer='Hane-Klocko', department='Human Resources', employee_id='27-2946273', ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', last_updated=datetime.datetime(2017, 12, 13, 0, 0), created=datetime.datetime(2016, 10, 24, 0, 0), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992)
# DataN(employer='Ernser LLC', department='Services', employee_id='07-6466085', ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 4, 25, 0, 0), created=datetime.datetime(2016, 1, 29, 0, 0), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# DataN(employer='Terry LLC', department='Accounting', employee_id='70-4864087', ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', last_updated=datetime.datetime(2017, 12, 24, 0, 0), created=datetime.datetime(2016, 12, 6, 0, 0), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005)
# DataN(employer='"Rolfson', department=' Price and Crooks"', employee_id='Business Development', ssn='77-0255816', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2017, 11, 11, 0, 0), created=datetime.datetime(2016, 7, 10, 0, 0), vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997)
# DataN(employer='"Romaguera', department=' Welch and Haley"', employee_id='Engineering', ssn='14-6523887', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', last_updated=datetime.datetime(2017, 12, 1, 0, 0), created=datetime.datetime(2016, 7, 23, 0, 0), vehicle_make='Acura', vehicle_model='RL', model_year=2003)
# DataN(employer='"Paucek', department=' Huels and Bauch"', employee_id='Accounting', ssn='21-1452824', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 8, 23, 0, 0), created=datetime.datetime(2016, 6, 26, 0, 0), vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002)
# DataN(employer='Hayes-Trantow', department='Support', employee_id='07-2855255', ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', last_updated=datetime.datetime(2017, 8, 16, 0, 0), created=datetime.datetime(2016, 10, 23, 0, 0), vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# DataN(employer='"Cruickshank', department=' Legros and Keebler"', employee_id='Research and Development', ssn='57-1590433', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', last_updated=datetime.datetime(2017, 9, 11, 0, 0), created=datetime.datetime(2016, 10, 22, 0, 0), vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999)
# DataN(employer='Mueller-Rath', department='Human Resources', employee_id='05-8069298', ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', last_updated=datetime.datetime(2017, 2, 21, 0, 0), created=datetime.datetime(2016, 1, 30, 0, 0), vehicle_make='Ford', vehicle_model='Mustang', model_year=1989)
# DataN(employer='"Schumm', department=' Schumm and Reichert"', employee_id='Engineering', ssn='73-3839744', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 2, 7, 0, 0), created=datetime.datetime(2016, 7, 8, 0, 0), vehicle_make='Lexus', vehicle_model='RX', model_year=2010)
# DataN(employer='Tromp-Leffler', department='Support', employee_id='02-6267170', ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', last_updated=datetime.datetime(2017, 8, 31, 0, 0), created=datetime.datetime(2016, 8, 29, 0, 0), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004)
# DataN(employer='Wolf LLC', department='Engineering', employee_id='53-8370994', ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara', last_updated=datetime.datetime(2017, 1, 12, 0, 0), created=datetime.datetime(2016, 10, 9, 0, 0), vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008)
# DataN(employer='Kulas-Corwin', department='Sales', employee_id='78-0632027', ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 3, 20, 0, 0), created=datetime.datetime(2016, 8, 19, 0, 0), vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# DataN(employer='"MacGyver', department=' Wiegand and Grant"', employee_id='Product Management', ssn='77-4182531', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 9, 10, 0, 0), created=datetime.datetime(2016, 7, 23, 0, 0), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007)
# DataN(employer="Kertzmann-O'Hara", department='Sales', employee_id='44-8015165', ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 1, 29, 0, 0), created=datetime.datetime(2016, 7, 13, 0, 0), vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006)
# DataN(employer='"Vandervort', department=' Bernier and Morissette"', employee_id='Human Resources', ssn='14-4998615', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 8, 10, 0, 0), created=datetime.datetime(2016, 12, 19, 0, 0), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# DataN(employer='King-Donnelly', department='Training', employee_id='82-0573004', ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', last_updated=datetime.datetime(2017, 8, 31, 0, 0), created=datetime.datetime(2016, 7, 29, 0, 0), vehicle_make='Dodge', vehicle_model='Neon', model_year=1995)
# DataN(employer='Harris Inc', department='Support', employee_id='53-7535536', ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 8, 13, 0, 0), created=datetime.datetime(2016, 3, 21, 0, 0), vehicle_make='BMW', vehicle_model='M', model_year=2001)
# DataN(employer='"Heidenreich', department=' Bergnaum and Smith"', employee_id='Training', ssn='04-7204163', first_name='Norton', last_name='Shailer', gender='Male', language='Czech', last_updated=datetime.datetime(2017, 1, 3, 0, 0), created=datetime.datetime(2016, 3, 18, 0, 0), vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988)
# DataN(employer='Altenwerth-Heidenreich', department='Research and Development', employee_id='58-3628686', ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha', last_updated=datetime.datetime(2017, 2, 11, 0, 0), created=datetime.datetime(2016, 12, 12, 0, 0), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993)
# DataN(employer='Gibson and Sons', department='Sales', employee_id='57-8173633', ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', last_updated=datetime.datetime(2018, 3, 21, 0, 0), created=datetime.datetime(2016, 2, 3, 0, 0), vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012)
# DataN(employer='Rodriguez LLC', department='Legal', employee_id='65-7310166', ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi', last_updated=datetime.datetime(2017, 1, 19, 0, 0), created=datetime.datetime(2016, 5, 20, 0, 0), vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992)
# DataN(employer='Donnelly-Crooks', department='Human Resources', employee_id='22-2943669', ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', last_updated=datetime.datetime(2017, 1, 29, 0, 0), created=datetime.datetime(2016, 8, 3, 0, 0), vehicle_make='BMW', vehicle_model='M5', model_year=2006)
# DataN(employer='Hyatt LLC', department='Training', employee_id='96-9647102', ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', last_updated=datetime.datetime(2017, 12, 22, 0, 0), created=datetime.datetime(2016, 2, 28, 0, 0), vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004)
# DataN(employer='Schuster Group', department='Research and Development', employee_id='72-4728604', ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 12, 24, 0, 0), created=datetime.datetime(2016, 3, 1, 0, 0), vehicle_make='Infiniti', vehicle_model='G', model_year=2005)
# DataN(employer='Homenick-Beer', department='Product Management', employee_id='01-9334133', ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', last_updated=datetime.datetime(2017, 4, 17, 0, 0), created=datetime.datetime(2016, 12, 17, 0, 0), vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992)
# DataN(employer='VonRueden-Torphy', department='Business Development', employee_id='10-6636122', ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', last_updated=datetime.datetime(2018, 3, 4, 0, 0), created=datetime.datetime(2016, 9, 24, 0, 0), vehicle_make='Lexus', vehicle_model='RX', model_year=2003)
# DataN(employer='"Mohr', department=' Harvey and Mitchell"', employee_id='Legal', ssn='64-7550101', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese', last_updated=datetime.datetime(2017, 2, 24, 0, 0), created=datetime.datetime(2016, 1, 4, 0, 0), vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004)
# DataN(employer='Keeling-Schroeder', department='Engineering', employee_id='82-2479019', ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian', last_updated=datetime.datetime(2017, 2, 16, 0, 0), created=datetime.datetime(2016, 5, 24, 0, 0), vehicle_make='Ford', vehicle_model='Escort', model_year=1997)
# DataN(employer='Gusikowski-Block', department='Legal', employee_id='41-1454732', ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', last_updated=datetime.datetime(2017, 8, 19, 0, 0), created=datetime.datetime(2016, 9, 10, 0, 0), vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990)
# DataN(employer='Pollich-Heathcote', department='Product Management', employee_id='12-2844710', ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', last_updated=datetime.datetime(2018, 1, 17, 0, 0), created=datetime.datetime(2016, 12, 21, 0, 0), vehicle_make='Volvo', vehicle_model='V70', model_year=2002)
# DataN(employer='Bogisich Inc', department='Human Resources', employee_id='34-7172919', ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', last_updated=datetime.datetime(2017, 9, 21, 0, 0), created=datetime.datetime(2016, 1, 27, 0, 0), vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# DataN(employer='Gutkowski Inc', department='Engineering', employee_id='83-4836768', ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori', last_updated=datetime.datetime(2017, 11, 12, 0, 0), created=datetime.datetime(2016, 12, 14, 0, 0), vehicle_make='Volvo', vehicle_model='XC90', model_year=2009)
# DataN(employer='Greenholt LLC', department='Sales', employee_id='84-5391800', ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', last_updated=datetime.datetime(2017, 9, 27, 0, 0), created=datetime.datetime(2016, 7, 17, 0, 0), vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000)
# DataN(employer='Hartmann Inc', department='Support', employee_id='26-7276512', ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', last_updated=datetime.datetime(2018, 1, 24, 0, 0), created=datetime.datetime(2016, 12, 20, 0, 0), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# DataN(employer='Zboncak-Gulgowski', department='Marketing', employee_id='05-0368584', ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', last_updated=datetime.datetime(2017, 7, 16, 0, 0), created=datetime.datetime(2016, 7, 30, 0, 0), vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999)
# DataN(employer='Altenwerth-Emard', department='Marketing', employee_id='30-5847411', ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', last_updated=datetime.datetime(2017, 5, 3, 0, 0), created=datetime.datetime(2016, 12, 26, 0, 0), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005)
# DataN(employer='Cronin Inc', department='Business Development', employee_id='08-3106397', ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', last_updated=datetime.datetime(2017, 7, 21, 0, 0), created=datetime.datetime(2016, 2, 9, 0, 0), vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# DataN(employer='"Murray', department=' Wolff and Little"', employee_id='Business Development', ssn='29-3578815', first_name='Donny', last_name='Laba', gender='Male', language='Japanese', last_updated=datetime.datetime(2017, 1, 18, 0, 0), created=datetime.datetime(2016, 4, 25, 0, 0), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# DataN(employer='Dibbert LLC', department='Support', employee_id='09-9620598', ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2018, 2, 20, 0, 0), created=datetime.datetime(2016, 10, 3, 0, 0), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# DataN(employer='Tromp Inc', department='Research and Development', employee_id='06-3360383', ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', last_updated=datetime.datetime(2017, 6, 10, 0, 0), created=datetime.datetime(2016, 9, 23, 0, 0), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993)
# DataN(employer='"Kub', department=' Koch and Ratke"', employee_id='Marketing', ssn='72-7830449', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', last_updated=datetime.datetime(2017, 1, 18, 0, 0), created=datetime.datetime(2016, 9, 1, 0, 0), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988)
# DataN(employer='Greenholt-Gusikowski', department='Engineering', employee_id='16-6006875', ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', last_updated=datetime.datetime(2018, 2, 9, 0, 0), created=datetime.datetime(2016, 5, 31, 0, 0), vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995)
# DataN(employer='"Tremblay', department=' Jacobs and Swift"', employee_id='Training', ssn='46-1648855', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', last_updated=datetime.datetime(2017, 4, 2, 0, 0), created=datetime.datetime(2016, 12, 11, 0, 0), vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996)
# DataN(employer='Bashirian-Moen', department='Training', employee_id='51-9115041', ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2018, 2, 2, 0, 0), created=datetime.datetime(2016, 7, 17, 0, 0), vehicle_make='Ford', vehicle_model='Explorer', model_year=2005)
# DataN(employer='Hudson-Gerhold', department='Human Resources', employee_id='62-2244500', ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', last_updated=datetime.datetime(2017, 1, 22, 0, 0), created=datetime.datetime(2016, 4, 29, 0, 0), vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992)
# DataN(employer='Balistreri Inc', department='Sales', employee_id='92-8183627', ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', last_updated=datetime.datetime(2017, 8, 31, 0, 0), created=datetime.datetime(2016, 10, 21, 0, 0), vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992)
# DataN(employer='"Eichmann', department=' Quigley and Macejkovic"', employee_id='Business Development', ssn='48-8059597', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', last_updated=datetime.datetime(2017, 9, 2, 0, 0), created=datetime.datetime(2016, 2, 23, 0, 0), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995)
# DataN(employer='Bosco-Kunde', department='Services', employee_id='55-1726090', ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', last_updated=datetime.datetime(2018, 2, 14, 0, 0), created=datetime.datetime(2016, 1, 28, 0, 0), vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000)
# DataN(employer='Ratke-Raynor', department='Legal', employee_id='60-6687797', ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2017, 6, 4, 0, 0), created=datetime.datetime(2016, 4, 23, 0, 0), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# DataN(employer='Bergstrom-Boyle', department='Marketing', employee_id='72-3121170', ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', last_updated=datetime.datetime(2018, 2, 8, 0, 0), created=datetime.datetime(2016, 10, 19, 0, 0), vehicle_make='Ford', vehicle_model='Probe', model_year=1996)
# DataN(employer='McLaughlin-Rohan', department='Legal', employee_id='47-1922172', ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy', last_updated=datetime.datetime(2017, 2, 13, 0, 0), created=datetime.datetime(2016, 4, 28, 0, 0), vehicle_make='Ford', vehicle_model='F250', model_year=1999)
# DataN(employer='"Schinner', department=' Swaniawski and Carter"', employee_id='Human Resources', ssn='93-3103060', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', last_updated=datetime.datetime(2017, 7, 8, 0, 0), created=datetime.datetime(2016, 6, 11, 0, 0), vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# DataN(employer='"Little', department=' Hagenes and McKenzie"', employee_id='Training', ssn='75-9906937', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', last_updated=datetime.datetime(2018, 2, 25, 0, 0), created=datetime.datetime(2016, 10, 8, 0, 0), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001)
# DataN(employer='"Gerlach', department=' Bahringer and Rutherford"', employee_id='Accounting', ssn='95-5604381', first_name='Annelise', last_name='Yushin', gender='Female', language='French', last_updated=datetime.datetime(2017, 8, 16, 0, 0), created=datetime.datetime(2016, 12, 22, 0, 0), vehicle_make='Ford', vehicle_model='Taurus', model_year=1998)
# DataN(employer='Gorczany LLC', department='Training', employee_id='62-8983936', ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', last_updated=datetime.datetime(2017, 4, 19, 0, 0), created=datetime.datetime(2016, 1, 29, 0, 0), vehicle_make='Nissan', vehicle_model='Armada', model_year=2005)
# DataN(employer='"Little', department=' Powlowski and Witting"', employee_id='Business Development', ssn='42-4459617', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', last_updated=datetime.datetime(2017, 9, 10, 0, 0), created=datetime.datetime(2016, 10, 20, 0, 0), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011)
# DataN(employer='King LLC', department='Research and Development', employee_id='39-4026042', ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 8, 30, 0, 0), created=datetime.datetime(2016, 5, 7, 0, 0), vehicle_make='Acura', vehicle_model='TL', model_year=2005)
# DataN(employer='Konopelski-Vandervort', department='Legal', employee_id='87-8332368', ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', last_updated=datetime.datetime(2017, 4, 17, 0, 0), created=datetime.datetime(2016, 3, 17, 0, 0), vehicle_make='Audi', vehicle_model='Q7', model_year=2007)
# DataN(employer='Reichel Group', department='Training', employee_id='10-5605387', ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2017, 3, 24, 0, 0), created=datetime.datetime(2016, 9, 15, 0, 0), vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005)
# DataN(employer='Gerhold-Marquardt', department='Research and Development', employee_id='25-6013938', ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', last_updated=datetime.datetime(2017, 11, 4, 0, 0), created=datetime.datetime(2016, 6, 17, 0, 0), vehicle_make='BMW', vehicle_model='Z3', model_year=1996)
# DataN(employer='Greenholt-Hermiston', department='Business Development', employee_id='66-9841280', ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', last_updated=datetime.datetime(2017, 7, 3, 0, 0), created=datetime.datetime(2016, 6, 9, 0, 0), vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999)
# DataN(employer='"Oberbrunner', department=' Donnelly and Gibson"', employee_id='Human Resources', ssn='83-2548521', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', last_updated=datetime.datetime(2017, 12, 3, 0, 0), created=datetime.datetime(2016, 12, 9, 0, 0), vehicle_make='Ford', vehicle_model='Mustang', model_year=1995)
# DataN(employer='Roberts Group', department='Product Management', employee_id='07-6620387', ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', last_updated=datetime.datetime(2017, 9, 6, 0, 0), created=datetime.datetime(2016, 10, 23, 0, 0), vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998)
# DataN(employer='Olson-Lynch', department='Business Development', employee_id='50-7113609', ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 3, 26, 0, 0), created=datetime.datetime(2016, 3, 22, 0, 0), vehicle_make='Honda', vehicle_model='Civic', model_year=2012)
# DataN(employer='"Quitzon', department=' Rempel and Hane"', employee_id='Business Development', ssn='03-4767523', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', last_updated=datetime.datetime(2017, 6, 24, 0, 0), created=datetime.datetime(2016, 4, 20, 0, 0), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001)
# DataN(employer='"Carroll', department=' Konopelski and Wunsch"', employee_id='Research and Development', ssn='43-4797129', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 8, 14, 0, 0), created=datetime.datetime(2016, 7, 2, 0, 0), vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008)
# DataN(employer='Howell LLC', department='Business Development', employee_id='70-2399476', ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', last_updated=datetime.datetime(2017, 10, 31, 0, 0), created=datetime.datetime(2016, 2, 3, 0, 0), vehicle_make='GMC', vehicle_model='3500', model_year=1998)
# DataN(employer='Johnson Inc', department='Services', employee_id='34-7741883', ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', last_updated=datetime.datetime(2018, 1, 4, 0, 0), created=datetime.datetime(2016, 1, 29, 0, 0), vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989)
# DataN(employer='Corwin and Sons', department='Legal', employee_id='15-8160997', ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', last_updated=datetime.datetime(2017, 6, 10, 0, 0), created=datetime.datetime(2016, 9, 27, 0, 0), vehicle_make='Toyota', vehicle_model='MR2', model_year=1993)
# DataN(employer='Zemlak LLC', department='Research and Development', employee_id='86-8667896', ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara', last_updated=datetime.datetime(2017, 2, 11, 0, 0), created=datetime.datetime(2016, 9, 19, 0, 0), vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012)
# DataN(employer='Toy-Jakubowski', department='Engineering', employee_id='17-8085199', ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', last_updated=datetime.datetime(2017, 7, 17, 0, 0), created=datetime.datetime(2016, 4, 30, 0, 0), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964)
# DataN(employer='"Murphy', department=' Windler and Bartoletti"', employee_id='Legal', ssn='02-6976472', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', last_updated=datetime.datetime(2017, 3, 5, 0, 0), created=datetime.datetime(2016, 6, 15, 0, 0), vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010)
# DataN(employer='Batz Inc', department='Support', employee_id='49-2738721', ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 3, 5, 0, 0), created=datetime.datetime(2016, 9, 23, 0, 0), vehicle_make='Ford', vehicle_model='Mustang', model_year=1985)
# DataN(employer='Jast and Sons', department='Services', employee_id='38-6141294', ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', last_updated=datetime.datetime(2018, 3, 2, 0, 0), created=datetime.datetime(2016, 5, 12, 0, 0), vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011)
# DataN(employer='Roberts LLC', department='Research and Development', employee_id='91-2028080', ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French', last_updated=datetime.datetime(2017, 10, 11, 0, 0), created=datetime.datetime(2016, 9, 10, 0, 0), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# DataN(employer='"Schultz', department=' Price and Walsh"', employee_id='Business Development', ssn='69-6328477', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian', last_updated=datetime.datetime(2017, 1, 25, 0, 0), created=datetime.datetime(2016, 7, 24, 0, 0), vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969)
# DataN(employer='"Zulauf', department=' Hudson and Wisozk"', employee_id='Research and Development', ssn='39-1896194', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', last_updated=datetime.datetime(2018, 3, 3, 0, 0), created=datetime.datetime(2016, 10, 26, 0, 0), vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# DataN(employer='Bode-Zulauf', department='Marketing', employee_id='42-0021775', ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', last_updated=datetime.datetime(2017, 1, 28, 0, 0), created=datetime.datetime(2016, 1, 12, 0, 0), vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988)
# DataN(employer='Windler Group', department='Legal', employee_id='16-2190623', ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz', last_updated=datetime.datetime(2017, 1, 25, 0, 0), created=datetime.datetime(2016, 5, 14, 0, 0), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972)
# DataN(employer='Jast-Quitzon', department='Human Resources', employee_id='67-5707294', ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati', last_updated=datetime.datetime(2017, 3, 3, 0, 0), created=datetime.datetime(2016, 5, 17, 0, 0), vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994)
# DataN(employer='Green-Waelchi', department='Engineering', employee_id='29-7065788', ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian', last_updated=datetime.datetime(2017, 9, 30, 0, 0), created=datetime.datetime(2016, 8, 1, 0, 0), vehicle_make='Ford', vehicle_model='Taurus', model_year=1991)
# DataN(employer='Brown Group', department='Accounting', employee_id='91-0435820', ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai', last_updated=datetime.datetime(2017, 1, 14, 0, 0), created=datetime.datetime(2016, 11, 29, 0, 0), vehicle_make='Toyota', vehicle_model='Celica', model_year=1995)
# DataN(employer='MacGyver-Hartmann', department='Accounting', employee_id='77-4207310', ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', last_updated=datetime.datetime(2017, 4, 1, 0, 0), created=datetime.datetime(2016, 12, 3, 0, 0), vehicle_make='Jeep', vehicle_model='Commander', model_year=2007)
# DataN(employer='McGlynn LLC', department='Support', employee_id='35-4393230', ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', last_updated=datetime.datetime(2017, 3, 23, 0, 0), created=datetime.datetime(2016, 3, 6, 0, 0), vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013)
# DataN(employer='"Little', department=' Herzog and Mertz"', employee_id='Legal', ssn='45-9164509', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', last_updated=datetime.datetime(2017, 10, 7, 0, 0), created=datetime.datetime(2016, 11, 11, 0, 0), vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995)
# DataN(employer='Kertzmann-Reichel', department='Research and Development', employee_id='67-0581933', ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', last_updated=datetime.datetime(2017, 11, 30, 0, 0), created=datetime.datetime(2016, 4, 27, 0, 0), vehicle_make='GMC', vehicle_model='Canyon', model_year=2004)
# DataN(employer='"Douglas', department=' Funk and Schowalter"', employee_id='Services', ssn='77-2512148', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', last_updated=datetime.datetime(2017, 8, 16, 0, 0), created=datetime.datetime(2016, 9, 15, 0, 0), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008)
# DataN(employer='Bayer-Kunze', department='Support', employee_id='86-6996270', ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', last_updated=datetime.datetime(2017, 10, 2, 0, 0), created=datetime.datetime(2016, 10, 16, 0, 0), vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988)
# DataN(employer='"Kiehn', department=' Hansen and Will"', employee_id='Support', ssn='94-8005696', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 7, 5, 0, 0), created=datetime.datetime(2016, 7, 23, 0, 0), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997)
# DataN(employer='Kling-Howe', department='Research and Development', employee_id='71-7470887', ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian', last_updated=datetime.datetime(2017, 11, 3, 0, 0), created=datetime.datetime(2016, 9, 8, 0, 0), vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991)
# DataN(employer='Quitzon-Morissette', department='Product Management', employee_id='81-5434446', ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2018, 2, 26, 0, 0), created=datetime.datetime(2016, 6, 16, 0, 0), vehicle_make='Ford', vehicle_model='Mustang', model_year=1998)
# DataN(employer='Bergstrom-Daniel', department='Marketing', employee_id='31-7381298', ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', last_updated=datetime.datetime(2017, 10, 15, 0, 0), created=datetime.datetime(2016, 11, 17, 0, 0), vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997)
# DataN(employer='"Johnston', department=' Leuschke and Stracke"', employee_id='Support', ssn='96-9321837', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', last_updated=datetime.datetime(2017, 2, 16, 0, 0), created=datetime.datetime(2016, 7, 26, 0, 0), vehicle_make='Scion', vehicle_model='xD', model_year=2011)
# DataN(employer='Lubowitz-Franecki', department='Product Management', employee_id='68-5287750', ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', last_updated=datetime.datetime(2017, 3, 28, 0, 0), created=datetime.datetime(2016, 6, 3, 0, 0), vehicle_make='Audi', vehicle_model='90', model_year=1991)
# DataN(employer='Nienow-Metz', department='Legal', employee_id='88-5601438', ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua', last_updated=datetime.datetime(2017, 2, 19, 0, 0), created=datetime.datetime(2016, 10, 24, 0, 0), vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998)
# DataN(employer='"Quitzon', department=' Stiedemann and Breitenberg"', employee_id='Services', ssn='76-1399493', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', last_updated=datetime.datetime(2017, 7, 1, 0, 0), created=datetime.datetime(2016, 8, 8, 0, 0), vehicle_make='Mercury', vehicle_model='Sable', model_year=2001)
# DataN(employer='Turner-Connelly', department='Research and Development', employee_id='92-1687621', ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', last_updated=datetime.datetime(2017, 6, 9, 0, 0), created=datetime.datetime(2016, 9, 17, 0, 0), vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990)
# DataN(employer='"Kling', department=' Prosacco and Wisoky"', employee_id='Accounting', ssn='77-0491080', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', last_updated=datetime.datetime(2017, 12, 26, 0, 0), created=datetime.datetime(2016, 6, 5, 0, 0), vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003)
# DataN(employer='"Von', department=' O\'Kon and Runolfsdottir"', employee_id='Research and Development', ssn='34-6414700', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', last_updated=datetime.datetime(2017, 12, 27, 0, 0), created=datetime.datetime(2016, 6, 30, 0, 0), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985)
# DataN(employer='McLaughlin-Botsford', department='Business Development', employee_id='60-2450272', ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', last_updated=datetime.datetime(2017, 8, 8, 0, 0), created=datetime.datetime(2016, 9, 9, 0, 0), vehicle_make='BMW', vehicle_model='8 Series', model_year=1995)
# DataN(employer='Mann-Stehr', department='Sales', employee_id='82-9383132', ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua', last_updated=datetime.datetime(2017, 2, 12, 0, 0), created=datetime.datetime(2016, 6, 21, 0, 0), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# DataN(employer='Smitham-Blick', department='Engineering', employee_id='07-3918459', ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', last_updated=datetime.datetime(2017, 6, 6, 0, 0), created=datetime.datetime(2016, 2, 17, 0, 0), vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990)
# DataN(employer='Reilly and Sons', department='Product Management', employee_id='00-2155545', ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', last_updated=datetime.datetime(2018, 2, 12, 0, 0), created=datetime.datetime(2016, 4, 15, 0, 0), vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993)
# DataN(employer='"Keeling', department=' Hansen and Mertz"', employee_id='Training', ssn='86-3420084', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', last_updated=datetime.datetime(2017, 7, 27, 0, 0), created=datetime.datetime(2016, 5, 23, 0, 0), vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009)
# DataN(employer='Mante Inc', department='Business Development', employee_id='39-8018810', ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', last_updated=datetime.datetime(2017, 3, 18, 0, 0), created=datetime.datetime(2016, 11, 16, 0, 0), vehicle_make='Volvo', vehicle_model='C70', model_year=1998)
# DataN(employer='Nicolas Group', department='Support', employee_id='75-2636577', ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew', last_updated=datetime.datetime(2017, 1, 19, 0, 0), created=datetime.datetime(2016, 6, 13, 0, 0), vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999)
# DataN(employer='"Sauer', department=' Mann and Kling"', employee_id='Accounting', ssn='89-3029716', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 1, 16, 0, 0), created=datetime.datetime(2016, 5, 26, 0, 0), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001)
# DataN(employer='"Hodkiewicz', department=' Rau and Ryan"', employee_id='Marketing', ssn='29-2776451', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', last_updated=datetime.datetime(2017, 5, 22, 0, 0), created=datetime.datetime(2016, 10, 23, 0, 0), vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007)
# DataN(employer='Prosacco LLC', department='Business Development', employee_id='53-6059808', ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya', last_updated=datetime.datetime(2017, 1, 23, 0, 0), created=datetime.datetime(2016, 8, 1, 0, 0), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007)
# DataN(employer='"Mante', department=' Roberts and Miller"', employee_id='Research and Development', ssn='98-1318396', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian', last_updated=datetime.datetime(2017, 2, 13, 0, 0), created=datetime.datetime(2016, 1, 22, 0, 0), vehicle_make='Infiniti', vehicle_model='QX', model_year=2005)
# DataN(employer='Farrell and Sons', department='Product Management', employee_id='85-3648779', ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', last_updated=datetime.datetime(2017, 6, 23, 0, 0), created=datetime.datetime(2016, 11, 7, 0, 0), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003)
# DataN(employer='Heathcote-Torp', department='Product Management', employee_id='77-2681193', ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', last_updated=datetime.datetime(2018, 2, 23, 0, 0), created=datetime.datetime(2016, 4, 5, 0, 0), vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006)
# DataN(employer='"Hilpert', department=' Kassulke and Gutkowski"', employee_id='Research and Development', ssn='02-6484055', first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali', last_updated=datetime.datetime(2017, 11, 19, 0, 0), created=datetime.datetime(2016, 7, 31, 0, 0), vehicle_make='Mitsubishi', vehicle_model='Tredia', model_year=1985)
# DataN(employer='"Will', department=' Lemke and O\'Hara"', employee_id='Marketing', ssn='68-7719884', first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish', last_updated=datetime.datetime(2017, 11, 25, 0, 0), created=datetime.datetime(2016, 10, 7, 0, 0), vehicle_make='Acura', vehicle_model='NSX', model_year=1996)
# DataN(employer='Schuppe-Dickinson', department='Services', employee_id='47-8932065', ssn='202-84-1146', first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2017, 4, 1, 0, 0), created=datetime.datetime(2016, 7, 21, 0, 0), vehicle_make='Chrysler', vehicle_model='LHS', model_year=2000)
# DataN(employer='Kling-Graham', department='Marketing', employee_id='08-4055205', ssn='203-35-7648', first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian', last_updated=datetime.datetime(2017, 12, 1, 0, 0), created=datetime.datetime(2016, 8, 2, 0, 0), vehicle_make='Volvo', vehicle_model='960', model_year=1992)
# DataN(employer='"MacGyver', department=' Armstrong and Murray"', employee_id='Research and Development', ssn='68-8311842', first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian', last_updated=datetime.datetime(2018, 2, 27, 0, 0), created=datetime.datetime(2016, 5, 19, 0, 0), vehicle_make='Subaru', vehicle_model='Outback', model_year=2011)
# ...
# DataN(employer='Goodwin Inc', department='Marketing', employee_id='73-2880950', ssn='858-27-9190', first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian', last_updated=datetime.datetime(2017, 2, 6, 0, 0), created=datetime.datetime(2016, 12, 25, 0, 0), vehicle_make='Suzuki', vehicle_model='Swift', model_year=1997)
# DataN(employer='Williamson-Lemke', department='Accounting', employee_id='80-9563373', ssn='860-67-0256', first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik', last_updated=datetime.datetime(2017, 1, 9, 0, 0), created=datetime.datetime(2016, 2, 6, 0, 0), vehicle_make='Toyota', vehicle_model='Tacoma', model_year=2001)
# DataN(employer='Reinger Inc', department='Engineering', employee_id='80-2005731', ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', last_updated=datetime.datetime(2017, 4, 15, 0, 0), created=datetime.datetime(2016, 6, 22, 0, 0), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007)
# DataN(employer='Stokes Inc', department='Training', employee_id='12-6635955', ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', last_updated=datetime.datetime(2018, 3, 30, 0, 0), created=datetime.datetime(2016, 9, 16, 0, 0), vehicle_make='BMW', vehicle_model='M5', model_year=2007)
# DataN(employer='"Dicki', department=' Green and White"', employee_id='Services', ssn='87-1017676', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 5, 3, 0, 0), created=datetime.datetime(2016, 2, 4, 0, 0), vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002)
# DataN(employer='"Thiel', department=' Parker and Hilpert"', employee_id='Marketing', ssn='20-2324966', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian', last_updated=datetime.datetime(2017, 2, 4, 0, 0), created=datetime.datetime(2016, 12, 28, 0, 0), vehicle_make='Acura', vehicle_model='ZDX', model_year=2011)
# DataN(employer='"Heidenreich', department=' Stehr and Huel"', employee_id='Sales', ssn='89-1713880', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 2, 3, 0, 0), created=datetime.datetime(2016, 2, 14, 0, 0), vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004)
# DataN(employer='Bartoletti Inc', department='Support', employee_id='77-7239839', ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', last_updated=datetime.datetime(2017, 5, 31, 0, 0), created=datetime.datetime(2016, 2, 2, 0, 0), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# DataN(employer='Douglas-Breitenberg', department='Business Development', employee_id='63-6285198', ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', last_updated=datetime.datetime(2018, 2, 24, 0, 0), created=datetime.datetime(2016, 12, 15, 0, 0), vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997)
# DataN(employer='Nitzsche-Walker', department='Engineering', employee_id='50-5681388', ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', last_updated=datetime.datetime(2018, 1, 25, 0, 0), created=datetime.datetime(2016, 10, 31, 0, 0), vehicle_make='Volvo', vehicle_model='S80', model_year=2001)
# DataN(employer='"Crist', department=' Leuschke and Grimes"', employee_id='Legal', ssn='09-8398802', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 10, 31, 0, 0), created=datetime.datetime(2016, 7, 17, 0, 0), vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986)
# DataN(employer='Emard Inc', department='Business Development', employee_id='49-2589434', ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2018, 3, 11, 0, 0), created=datetime.datetime(2016, 11, 4, 0, 0), vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# DataN(employer='Abshire Inc', department='Research and Development', employee_id='55-8987515', ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', last_updated=datetime.datetime(2017, 9, 29, 0, 0), created=datetime.datetime(2016, 11, 14, 0, 0), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007)
# DataN(employer='"Thompson', department=' Parker and Moen"', employee_id='Research and Development', ssn='46-1484106', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana', last_updated=datetime.datetime(2017, 1, 19, 0, 0), created=datetime.datetime(2016, 6, 24, 0, 0), vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991)
# DataN(employer='"Morissette', department=' Rowe and Muller"', employee_id='Engineering', ssn='73-9912953', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', last_updated=datetime.datetime(2017, 3, 3, 0, 0), created=datetime.datetime(2016, 6, 21, 0, 0), vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998)
# DataN(employer='"Lueilwitz', department=' Stokes and Kassulke"', employee_id='Marketing', ssn='16-1937114', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 5, 8, 0, 0), created=datetime.datetime(2016, 2, 27, 0, 0), vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000)
# DataN(employer='"Glover', department=' Jacobs and Heidenreich"', employee_id='Sales', ssn='72-1577952', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', last_updated=datetime.datetime(2018, 3, 22, 0, 0), created=datetime.datetime(2016, 4, 27, 0, 0), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# DataN(employer='Cummings-Mertz', department='Sales', employee_id='78-2291834', ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', last_updated=datetime.datetime(2017, 12, 6, 0, 0), created=datetime.datetime(2016, 6, 10, 0, 0), vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# DataN(employer='Wilderman-Grimes', department='Engineering', employee_id='39-6055619', ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', last_updated=datetime.datetime(2017, 7, 23, 0, 0), created=datetime.datetime(2016, 7, 8, 0, 0), vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964)
# DataN(employer='Schultz-Medhurst', department='Support', employee_id='56-6050344', ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', last_updated=datetime.datetime(2017, 3, 14, 0, 0), created=datetime.datetime(2016, 8, 19, 0, 0), vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993)
# DataN(employer='Wunsch-Gleason', department='Services', employee_id='28-3015726', ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', last_updated=datetime.datetime(2017, 12, 3, 0, 0), created=datetime.datetime(2016, 6, 12, 0, 0), vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000)
# DataN(employer='"Witting', department=' Schuster and Barton"', employee_id='Research and Development', ssn='54-4161357', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', last_updated=datetime.datetime(2017, 1, 11, 0, 0), created=datetime.datetime(2016, 3, 14, 0, 0), vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998)
# DataN(employer='Harber-Legros', department='Training', employee_id='59-9280036', ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri', last_updated=datetime.datetime(2017, 1, 13, 0, 0), created=datetime.datetime(2016, 6, 11, 0, 0), vehicle_make='Toyota', vehicle_model='Camry', model_year=2008)
# DataN(employer='"Daugherty', department=' Gislason and Kreiger"', employee_id='Training', ssn='25-5973403', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', last_updated=datetime.datetime(2018, 2, 4, 0, 0), created=datetime.datetime(2016, 10, 5, 0, 0), vehicle_make='Infiniti', vehicle_model='G', model_year=2004)
# DataN(employer='"O\'Connell', department=' Raynor and Veum"', employee_id='Sales', ssn='16-0843654', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', last_updated=datetime.datetime(2017, 8, 11, 0, 0), created=datetime.datetime(2016, 1, 18, 0, 0), vehicle_make='Subaru', vehicle_model='SVX', model_year=1994)
# DataN(employer='Schumm Inc', department='Services', employee_id='18-8360445', ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', last_updated=datetime.datetime(2018, 1, 29, 0, 0), created=datetime.datetime(2016, 11, 24, 0, 0), vehicle_make='BMW', vehicle_model='M6', model_year=2009)
# DataN(employer='Zulauf Inc', department='Accounting', employee_id='46-7067366', ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 2, 10, 0, 0), created=datetime.datetime(2016, 8, 27, 0, 0), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# DataN(employer='"Stanton', department=' Price and Wehner"', employee_id='Services', ssn='16-5769119', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian', last_updated=datetime.datetime(2017, 1, 9, 0, 0), created=datetime.datetime(2016, 3, 18, 0, 0), vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996)
# DataN(employer='"Ziemann', department=' Denesik and Casper"', employee_id='Research and Development', ssn='71-6097002', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', last_updated=datetime.datetime(2017, 3, 27, 0, 0), created=datetime.datetime(2016, 9, 14, 0, 0), vehicle_make='Lexus', vehicle_model='GS', model_year=2013)
# DataN(employer='Terry and Sons', department='Research and Development', employee_id='06-9390159', ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2017, 12, 19, 0, 0), created=datetime.datetime(2016, 5, 30, 0, 0), vehicle_make='Audi', vehicle_model='S6', model_year=2011)
# DataN(employer='"Herzog', department=' Stehr and Quitzon"', employee_id='Engineering', ssn='38-5385705', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2018, 3, 6, 0, 0), created=datetime.datetime(2016, 6, 9, 0, 0), vehicle_make='Nissan', vehicle_model='Armada', model_year=2008)
# DataN(employer='"Collier', department=' Hilll and Hagenes"', employee_id='Training', ssn='15-6651242', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', last_updated=datetime.datetime(2017, 9, 5, 0, 0), created=datetime.datetime(2016, 2, 12, 0, 0), vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991)
# DataN(employer='"Reynolds', department=' Nicolas and Morar"', employee_id='Engineering', ssn='48-3998718', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 12, 8, 0, 0), created=datetime.datetime(2016, 11, 9, 0, 0), vehicle_make='Volvo', vehicle_model='S60', model_year=2005)
# DataN(employer='"Heller', department=' Kihn and Bartoletti"', employee_id='Research and Development', ssn='56-9393666', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', last_updated=datetime.datetime(2018, 1, 6, 0, 0), created=datetime.datetime(2016, 2, 22, 0, 0), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000)
# DataN(employer='Christiansen LLC', department='Sales', employee_id='66-1175841', ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', last_updated=datetime.datetime(2018, 3, 27, 0, 0), created=datetime.datetime(2016, 6, 14, 0, 0), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991)
# DataN(employer='Orn Inc', department='Human Resources', employee_id='38-4356300', ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', last_updated=datetime.datetime(2017, 7, 23, 0, 0), created=datetime.datetime(2016, 2, 28, 0, 0), vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# DataN(employer='"Flatley', department=' Senger and Bernier"', employee_id='Services', ssn='72-2633200', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', last_updated=datetime.datetime(2017, 3, 7, 0, 0), created=datetime.datetime(2016, 7, 9, 0, 0), vehicle_make='Kia', vehicle_model='Sedona', model_year=2012)
# DataN(employer='"Hilll', department=' Kunze and Beer"', employee_id='Human Resources', ssn='90-4168298', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 4, 1, 0, 0), created=datetime.datetime(2016, 11, 22, 0, 0), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003)
# DataN(employer='Franecki LLC', department='Services', employee_id='63-7802530', ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', last_updated=datetime.datetime(2017, 5, 13, 0, 0), created=datetime.datetime(2016, 3, 24, 0, 0), vehicle_make='Acura', vehicle_model='TL', model_year=1999)
# DataN(employer='Reilly-Jakubowski', department='Marketing', employee_id='77-6363112', ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', last_updated=datetime.datetime(2017, 11, 27, 0, 0), created=datetime.datetime(2016, 12, 12, 0, 0), vehicle_make='BMW', vehicle_model='X3', model_year=2011)
# DataN(employer='Bins-Gerhold', department='Sales', employee_id='89-9965641', ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', last_updated=datetime.datetime(2017, 6, 1, 0, 0), created=datetime.datetime(2016, 7, 20, 0, 0), vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994)
# DataN(employer='Olson-Johnson', department='Support', employee_id='36-7761827', ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', last_updated=datetime.datetime(2017, 7, 3, 0, 0), created=datetime.datetime(2016, 11, 23, 0, 0), vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003)
# DataN(employer='Cronin LLC', department='Services', employee_id='83-8730953', ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', last_updated=datetime.datetime(2017, 7, 31, 0, 0), created=datetime.datetime(2016, 10, 27, 0, 0), vehicle_make='Toyota', vehicle_model='Camry', model_year=2012)
# DataN(employer='Little-Hansen', department='Business Development', employee_id='45-8154226', ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', last_updated=datetime.datetime(2017, 8, 2, 0, 0), created=datetime.datetime(2016, 7, 27, 0, 0), vehicle_make='Infiniti', vehicle_model='FX', model_year=2006)
# DataN(employer='"Christiansen', department=' Ondricka and O\'Connell"', employee_id='Marketing', ssn='32-7034344', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', last_updated=datetime.datetime(2017, 3, 27, 0, 0), created=datetime.datetime(2016, 9, 4, 0, 0), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999)
# DataN(employer='Bednar LLC', department='Support', employee_id='16-6342889', ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', last_updated=datetime.datetime(2017, 6, 10, 0, 0), created=datetime.datetime(2016, 4, 29, 0, 0), vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)

# %% [markdown]
# ### Goal 3

# %%
data_filter = filter(lambda x: x.last_updated < datetime.strptime('3/1/2017', '%d/%m/%Y'),next(iter(all_data)))

for x in data_filter:
    print(x)
# Out:
# DataN(employer='Bechtelar-McCullough', department='Sales', employee_id='01-1786654', ssn='390-74-3062', first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian', last_updated=datetime.datetime(2017, 1, 1, 0, 0), created=datetime.datetime(2016, 11, 14, 0, 0), vehicle_make='Audi', vehicle_model='TT', model_year=2002)
# DataN(employer='"Parisian', department=' Kutch and Boyle"', employee_id='Services', ssn='65-6774148', first_name='Glyn', last_name='Mc Giffin', gender='Female', language='Zulu', last_updated=datetime.datetime(2017, 1, 2, 0, 0), created=datetime.datetime(2016, 3, 24, 0, 0), vehicle_make='Chevrolet', vehicle_model='Classic', model_year=2004)
# DataN(employer='Stark-Runte', department='Support', employee_id='62-6777890', ssn='669-12-9323', first_name='Peter', last_name='Ketteman', gender='Male', language='Hiri Motu', last_updated=datetime.datetime(2017, 1, 2, 0, 0), created=datetime.datetime(2016, 11, 19, 0, 0), vehicle_make='Hyundai', vehicle_model='Sonata', model_year=2004)

# %% [markdown]
# ### Goal 4

# %%
counter_dict_male = dict()
counter_dict_female = dict()
for data in next(iter(all_data)):
    if data.gender == "Female":
        if not(data.vehicle_make + data.gender in counter_dict_female.keys()):
            counter_dict_female[data.vehicle_make + data.gender] = 0
        counter_dict_female[data.vehicle_make + data.gender] += 1
    else:
        if not(data.vehicle_make + data.gender in counter_dict_male.keys()):
            counter_dict_male[data.vehicle_make + data.gender] = 0
        counter_dict_male[data.vehicle_make + data.gender] += 1

# %%
female_key = [data_dict_key[:-6] for data_dict_key,data_dict_value  in counter_dict_female.items() if data_dict_value == max(counter_dict_female.values())]
print(female_key)
# Out:
# ['Ford', 'Chevrolet']

# %%
male_key = [data_dict_key[:-4] for data_dict_key,data_dict_value  in counter_dict_male.items() if data_dict_value == max(counter_dict_male.values())]
print(male_key)
# Out:
# ['Ford']
